# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
datawalk = pd.read_csv('walk.txt', sep=",", header=None)
datawalk.columns = ["x", "y", "z"]
datawalk['x'] = datawalk['x'].map(lambda x: x.lstrip('('))
datawalk['z'] = datawalk['z'].map(lambda x: x.rstrip(')'))
datawalk['Type'] = 'Walk'
datawalk.head()
# Out:
#      x    y      z  Type
# 0  0.0  0.0   -0.1  Walk
# 1  0.0  0.0   -0.1  Walk
# 2  0.0  0.0   -0.1  Walk
# 3  0.0  0.0   -0.1  Walk
# 4  0.0  0.0   -0.1  Walk

# %%
dataidle = pd.read_csv('Idle.txt', sep=",", header=None)
dataidle.columns = ["x", "y", "z"]
dataidle['x'] = dataidle['x'].map(lambda x: x.lstrip('('))
dataidle['z'] = dataidle['x'].map(lambda x: x.lstrip(')'))
dataidle['Type'] = 'Idle'
dataidle.head()
# Out:
#      x    y    z  Type
# 0  0.0  0.0  0.0  Idle
# 1  0.0  0.0  0.0  Idle
# 2  0.0  0.0  0.0  Idle
# 3  0.0  0.0  0.0  Idle
# 4  0.0  0.0  0.0  Idle

# %%
dataJump = pd.read_csv('Jump.txt', sep=",", header=None)
dataJump.columns = ["x", "y", "z"]
dataJump['x'] = dataJump['x'].map(lambda x: x.lstrip('('))
dataJump['z'] = dataJump['z'].map(lambda x: x.rstrip(')'))
dataJump['Type'] = 'Jump'
dataJump.head()
# Out:
#       x    y     z  Type
# 0  -0.1  0.0   0.0  Jump
# 1  -0.1  0.0   0.0  Jump
# 2  -0.1  0.0   0.0  Jump
# 3  -0.1  0.0   0.0  Jump
# 4  -0.1  0.0   0.0  Jump

# %%
data = datawalk
data.append(dataidle)
data.append(dataJump)
# Out:
#          x    y      z  Type
# 0      0.0  0.0   -0.1  Walk
# 1      0.0  0.0   -0.1  Walk
# 2      0.0  0.0   -0.1  Walk
# 3      0.0  0.0   -0.1  Walk
# 4      0.0  0.0   -0.1  Walk
# ...    ...  ...    ...   ...
# 1143  -0.1  0.0    0.0  Jump
# 1144  -0.1  0.0    0.0  Jump
# 1145  -0.1  0.0    0.0  Jump
# 1146  -0.1  0.0    0.0  Jump
# 1147  -0.1  0.0    0.0  Jump
#
# [2528 rows x 4 columns]

# %%
y = data['Type'].values
X = data[['x','y','z']]

##data is splitted for train and test
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size = 0.20, random_state = 21, stratify = y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a66a08b3f462> in <module>
#       3
#       4 ##data is splitted for train and test
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X , y, test_size = 0.20, random_state = 21, stratify = y)
#
# NameError: name 'train_test_split' is not defined
